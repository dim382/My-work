# %% [markdown]
# # Підсумкова контрольна робота КСВД

# %% [markdown]
# # **Завдання 1**

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Прочитайте CSV файл

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79e6c86d-c3ce-4d61-81d7-eeb55b8f7cbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79e6c86d-c3ce-4d61-81d7-eeb55b8f7cbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding='latin1')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# 2. Виведіть перші п'ять рядків

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# 3. Виведіть розміри датасету, перевірте наявність пропусків, дублікатів.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.shape
# Out:
# (995, 28)

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4. Якщо є пропуски, замінить тип даних на float і середнє значення за
# стовпцем.

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
        try:
            df[col] = df[col].astype(float)
            df[col].fillna(df[col].mean(), inplace=True)
        except ValueError:
            continue

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             0
# country_rank                                 0
# channel_type_rank                            0
# video_views_for_the_last_30_days             0
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days                 0
# created_year                                 0
# ...

# %%
for col in ['created_month', 'category', 'Country', 'Abbreviation', 'channel_type']:
    if col in df.columns and df[col].isnull().sum() > 0:
        mode_val = df[col].mode()[0]
        df[col].fillna(mode_val, inplace=True)
# Out:
# <ipython-input-16-323844a1a5a8>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mode_val, inplace=True)

# %% [markdown]
# 5. Ще раз перевірте кількість пропусків.

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %% [markdown]
# 6. Перевірте, скільки унікальних країн представлено у колонці "Country

# %%
df['Country'].nunique()
# Out:
# 49

# %% [markdown]
# 7. Побудуйте діаграму розподілу переглядів (використовуйте kind='hist'):

# %%
df['video views'].plot(kind='hist', bins=30, color='skyblue', edgecolor='black', figsize=(8, 5))
plt.title('Розподіл переглядів')
plt.xlabel('Кількість переглядів')
plt.ylabel('Кількість каналів')
plt.grid(True)
plt.show()

# %% [markdown]
# 8. Визначте максимальну, мінімальну, середню кількість переглядів
# (використовуйте методи max, min, mean)

# %%
df['video views'].max()
# Out:
# 228000000000.0

# %%
df['video views'].min()
# Out:
# 0.0

# %%
df['video views'].mean()
# Out:
# np.float64(11039537052.03819)

# %% [markdown]
# 9. Знайдіть країну, де найбільше відео було завантажено на YouTube

# %%
top_country = df.groupby('Country')['uploads'].sum().idxmax()
top_country
# Out:
# 'India'

# %% [markdown]
# 10. Знайдіть відео (виведіть його назву) з найбільшою та найменшою
# кількістю завантажень uploads

# %%
max_upload_title = df[df['uploads'] == df['uploads'].max()]['Title'].values[0]
min_upload_title = df[df['uploads'] == df['uploads'].min()]['Title'].values[0]

print("Найбільше завантажень:", max_upload_title)
print("Найменше завантажень:", min_upload_title)
# Out:
# Найбільше завантажень: ABP NEWS
# Найменше завантажень: Music

# %% [markdown]
# # **Завдання 2**

# %% [markdown]
# 1.Загрузіть цей файл

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e2a8ba34-3680-4d70-a0e9-b4e93f3e0547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2a8ba34-3680-4d70-a0e9-b4e93f3e0547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_2 = pd.read_csv('shopping_trends.csv', encoding='latin1')
df_2
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# 2. Перевірте розмір таблиці, наявність пропусків, тип
# стовпців. Перейменуйте назви стовпців: Змініть прописні букви на строчні
# (маленькі) та пробіл на підкреслення

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df_2.shape
# Out:
# (3900, 19)

# %%
df_2.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df_2.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df_2.columns = df_2.columns.str.lower().str.replace(' ', '_')
df_2.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'payment_method',
#        'shipping_type', 'discount_applied', 'promo_code_used',
#        'previous_purchases', 'preferred_payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# Побудуйте графіки з використанням
# бібліотеки seaborn.

# %% [markdown]
# 1. Гістограма віку (age)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_2['age'], bins=30, kde=False, color='skyblue')
plt.title('Гістограма віку клієнтів')
plt.xlabel('Вік')
plt.ylabel('Кількість')
plt.show()

# %% [markdown]
# 2.Порівняння розподілу покупок за статтею (item_purchased)

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df_2, y='item_purchased', order=df_2['item_purchased'].value_counts().index, palette='viridis')
plt.title('Розподіл покупок за товаром')
plt.xlabel('Кількість покупок')
plt.ylabel('Товар')
plt.show()
# Out:
# <ipython-input-35-3b16d7e6ad7e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_2, y='item_purchased', order=df_2['item_purchased'].value_counts().index, palette='viridis')

# %% [markdown]
# 3.Залежність між віком та сумою покупок (purchase_amount)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_2, x='age', y='purchase_amount_(usd)', alpha=0.5)
plt.title('Залежність віку від суми покупок')
plt.xlabel('Вік')
plt.ylabel('Сума покупки (USD)')
plt.show()

# %% [markdown]
# 4.Графік розподілу оцінок товарів (review_rating)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_2['review_rating'], bins=10, kde=False, color='coral')
plt.title('Розподіл оцінок товарів')
plt.xlabel('Оцінка')
plt.ylabel('Кількість')
plt.show()

# %% [markdown]
# 5.Категоріальна діаграма для статі (gender)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df_2, x='gender', palette='pastel')
plt.title('Розподіл покупок за статтю')
plt.xlabel('Стать')
plt.ylabel('Кількість покупок')
plt.show()
# Out:
# <ipython-input-39-936db1f4c010>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_2, x='gender', palette='pastel')

# %% [markdown]
# 6.Залежність між рейтингом і сумою покупок (review_rating і
# purchase_amount)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_2, x='review_rating', y='purchase_amount_(usd)', alpha=0.6)
plt.title('Залежність між рейтингом і сумою покупок')
plt.xlabel('Рейтинг')
plt.ylabel('Сума покупки (USD)')
plt.show()

# %% [markdown]
# # **Завдання 3**

# %% [markdown]
# 1. Створіть горизонтальну діаграму з мітками на основі даних про
# врожайність пшениці (data.wheat()) за допомогою бібліотеки Altair.
# Задайте вісь x для врожайності пшениці, вісь y для років, а текстові
# мітки відображайте значення врожайності пшениці на відповідних
# роках

# %%
import altair as alt
from vega_datasets import data
import pandas as pd

wheat = data.wheat()

chart = alt.Chart(wheat).mark_bar().encode(
    x=alt.X('wheat:Q', title='Врожайність пшениці'),
    y=alt.Y('year:O', title='Рік', axis=alt.Axis(labelAngle=0)),
    tooltip=['year', 'wheat']
).properties(
    title='Врожайність пшениці за роками'
)

text = chart.mark_text(align='left', dx=10).encode(
    text=alt.Text('wheat:Q', format='.1f')
)

final_chart = (chart + text).properties(height=300)

final_chart.show()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# 2. Створіть багатошарову діаграму на основі даних про виробництво
# електроенергії в штаті Айова (data.iowa_electricity()) за допомогою
# бібліотеки Altair . Вісь x представляє роки, вісь y відображає чисте
# виробництво електроенергії (net_generation), а кожен шар діаграми
# позначає різні джерела енергії (source). Встановіть прозорість (opacity)
# для стовпців на рівні 0.7.

# %%
iowa = data.iowa_electricity()

base = alt.Chart(iowa).encode(
    x='year:O',
    y='net_generation:Q',
    color='source:N'
)

bars = base.mark_bar(opacity=0.7)

bars.properties(
    width=600,
    height=400,
    title='Виробництво електроенергії в Айові за джерелами'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# 3. Створіть графік за допомогою бібліотеки Plotly (scatter plot) для даних
# ірисів (iris dataset), де:
# Вісь X (x-axis) відповідає ширині чашелистика (sepal width).
# Вісь Y (y-axis) відповідає довжині чашелистика (sepal length).
# Кожен пункт на графіку має розмір, який залежить від довжини
# пелюстки (petal length).
# Кожен пункт на графіку має різний колір в залежності від виду
# (species).
# При наведенні на пункт повинні відображатися додаткові дані, такі як
# ширина пелюстки (petal width)

# %%
import plotly.express as px
from vega_datasets import data as vdata

iris = vdata.iris()

fig = px.scatter(
    iris,
    x='sepalWidth',
    y='sepalLength',
    size='petalLength',
    color='species',
    hover_data=['petalWidth'],
    title='Іриси: довжина і ширина чашолистика'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Висновок за виконані завдання:**
# **Завдання 1**(Аналіз датасету Global YouTube Statistics 2023):
# Було проведено базовий аналіз датасету статистики YouTube. Виконано завантаження, первинний огляд (розміри, пропуски, дублікати). Пропуски були оброблені шляхом заміни на середнє значення після приведення стовпців до типу float. Визначено кількість унікальних країн, побудовано гістограму розподілу переглядів, знайдено екстремальні та середні значення переглядів. Також визначено країну з найбільшою кількістю завантажених відео та назви відео з найбільшою та найменшою кількістю завантажень.
#
# **Завдання 2** (Аналіз датасету Customer Shopping Trends Dataset):
# Завантажено та підготовлено датасет про тренди покупок клієнтів (перейменовано стовпці, перевірено розмір, пропуски, типи даних). За допомогою бібліотеки Seaborn побудовано ряд графіків для візуалізації різних аспектів даних.
#
# **Завдання 3**(Візуалізація з використанням Altair та Plotly):
# За допомогою бібліотеки Altair створено горизонтальну стовпчасту діаграму з мітками, що відображає врожайність пшениці за роками з набору даних data.wheat().Також за допомогою Altair побудовано багатошарову діаграму, що візуалізує виробництво електроенергії в штаті Айова за роками для різних джерел енергії з набору даних data.iowa_electricity(), з встановленою прозорістю для стовпців.
# За допомогою бібліотеки Plotly створено інтерактивний scatter plot для набору даних iris, де координати точок відповідають ширині та довжині чашелистика, розмір залежить від довжини пелюстки, а колір - від виду ірису. При наведенні відображається додаткова інформація про ширину пелюстки.
