# %% [markdown]
# # Завдання 1

# %% [markdown]
# **1. Прочитайте CSV файл (використовуйте метод read_csv):**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e31b2ac0-8ab6-4ea4-a03e-07ff1e5afe04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e31b2ac0-8ab6-4ea4-a03e-07ff1e5afe04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding='windows-1252')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# **2. Виведіть перші п'ять рядків (використовується метод head):**

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# **3. Виведіть розміри датасету (використовуйте метод shape):**

# %%
df.shape
# Out:
# (995, 28)

# %% [markdown]
# **4. Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків  у кожному зі стовпців (використовуйте методи isna та sum).
# Якщо є пропуски, замінить їх на NaN, потім тип даних на числовий.**

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %% [markdown]
# **5. Замініть комірки з пропущеними значенями на середні за стовпцем. І тип даних на float.**

# %%
df_clean = df.copy()

df_clean = df_clean.apply(pd.to_numeric, errors='ignore')


for col in df_clean.select_dtypes(include=['number']).columns:
    df_clean[col] = df_clean[col].fillna(df_clean[col].mean()).astype(float)
# Out:
# <ipython-input-62-b08e630959db>:3: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_clean = df_clean.apply(pd.to_numeric, errors='ignore')

# %% [markdown]
# **6.Перевіряємо чи змінились пропущені значення**

# %%
df_clean.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             0
# country_rank                                 0
# channel_type_rank                            0
# video_views_for_the_last_30_days             0
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days                 0
# created_year                                 0
# ...

# %% [markdown]
# **7. Перевірте, скільки унікальних країн представлено у колонці "Country"**

# %%
unique_countries = df['Country'].nunique()
unique_countries
# Out:
# 49

# %% [markdown]
# **8. Побудуйте діаграму розподілу переглядів (використовуйте kind='hist'):**

# %%
plt.figure(figsize=(10, 5))
df['video views'].hist(bins=50, color='skyblue', edgecolor='black')
plt.title('Розподіл переглядів на YouTube')
plt.xlabel('Кількість переглядів')
plt.ylabel('Кількість каналів')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **9. Визначте максимальну, мінімальну, середню кількість переглядів (використовуйте методи max, min, mean)**

# %%
df['video views'].max()
# Out:
# 228000000000.0

# %%
df['video views'].min()
# Out:
# 0.0

# %%
df['video views'].mean()
# Out:
# np.float64(11039537052.03819)

# %% [markdown]
# **10.Знайдіть країну, де найбільше відео було завантажено на YouTube**

# %%
country_uploads = df.groupby('Country')['uploads'].sum().idxmax()
country_uploads
# Out:
# 'India'

# %% [markdown]
# **11. Знайдіть відео (виведіть його назву) з найбільшою та найменшою кількістю завантажень uploads.**

# %%
# Канал з найбільшою кількістю відео
most_uploads = df.loc[df['uploads'].idxmax()]['Youtuber']
most_uploads
# Out:
# 'ABP NEWS'

# %%
# Канал з найменшою кількістю відео
least_uploads = df.loc[df['uploads'].idxmin()]['Youtuber']
least_uploads
# Out:
# 'Music'

# %% [markdown]
# ## Висновки :
# 1. У датасеті є пропущені дані в деяких країнових або освітніх показниках.
# 2. Максимальна кількість переглядів у нас вийшла 228000000000
# 3. Максимальна кількість завантажень відео є в країні - India
# 4. Канал з найбільшою кількістю відео ABP NEWS , як зясувалось це канал Індійського походження

# %% [markdown]
# # Завдання 2.

# %% [markdown]
# **1. Прочитайте csv файл (метод read_csv)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-77f1b3fe-bf71-46a5-9266-8a1e19e99346" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77f1b3fe-bf71-46a5-9266-8a1e19e99346">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_1 = pd.read_csv('bestsellers with categories.csv', encoding='ISO-8859-1')
df_1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# **2.Виведіть перші 10 рядків (метод head)**

# %%
df_1.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# ...

# %% [markdown]
# **3.Виведіть розміри датасету (метод shape)**

# %%
df_1.shape
# Out:
# (550, 7)

# %%
df_1.shape[0]
# Out:
# 550

# %% [markdown]
# **4.Змініть назви всіх колонок: назва з маленької букви, без пробілів через підкреслення. df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']**

# %%
df_1.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
df_1
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# **5. Вивести кількість пропусків у кожному стовпчику.
# Чи є в якихось змінних пропуски? (Так / ні)**

# %%
df_1.isna().sum()
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %%
print("Пропуски є?" , "Так" if df_1.isna().sum().any() else "Ні")
# Out:
# Пропуски є? Ні

# %% [markdown]
# **6. За допомогою методу unique  перевірте. Які є унікальні жанри в стовпці genre
# Які є унікальні жанри?**

# %%
print("Унікальні жанри:", df_1['genre'].unique())
# Out:
# Унікальні жанри: ['Non Fiction' 'Fiction']

# %% [markdown]
# **7.Визначте максимальну, мінімальну, медіанну ціну за допомогою методів  max, min, mean, median**

# %% [markdown]
# Максимальна ціна?

# %%
df_1['price'].max()
# Out:
# 105

# %% [markdown]
# Мінімальна ціна?

# %%
df_1['price'].min()
# Out:
# 0

# %% [markdown]
#  Середня ціна?

# %%
df_1['price'].mean()
# Out:
# np.float64(13.1)

# %% [markdown]
# Медіанна ціна?

# %%
df_1['price'].median()
# Out:
# 11.0

# %% [markdown]
# **8.Виконайте наступні завдання з пошуку і сортування даних**

# %% [markdown]
# Який рейтинг у датасеті найвищий?

# %%
df_1['user_rating'].max()
# Out:
# 4.9

# %% [markdown]
# Скільки книг мають такий рейтинг?

# %%
len(df_1[df_1['user_rating'] == df_1['user_rating'].max()])
# Out:
# 52

# %% [markdown]
# Яка книга має найбільше відгуків?

# %%
most_reviewed = df_1[df_1['reviews'] == df_1['reviews'].max()]
most_reviewed['name'].values[0]
# Out:
# 'Where the Crawdads Sing'

# %% [markdown]
# З тих книг, що потрапили до Топ-50 у 2010 році, яка книга найдорожча ?

# %%
book_2010 = df_1[df_1['year'] == 2010]
most_expensive_2010 = book_2010[book_2010['price'] == book_2010['price'].max()]
most_expensive_2010['name'].values[0]
# Out:
# 'Publication Manual of the American Psychological Association, 6th Edition'

# %% [markdown]
# Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або метод isin)?

# %%
high_rating = df_1[(df_1['user_rating'] == 4.9) & (df_1['year'].isin([2010, 2011]))]
high_rating.shape[0]
# Out:
# 1

# %% [markdown]
# **9.Вивести максимальну і  мінімальну ціну для жанру Fiction I NonFiction (за допомогою методів  groupby та agg, для підрахунку мінімальних та максимальних значень використовуйте max та min). Використовуйте тількі потрібні вам стовпці.**

# %%
price_by_genre = df_1.groupby('genre')['price'].agg(['min', 'max'])
price_by_genre
# Out:
#              min  max
# genre
# Fiction        0   82
# Non Fiction    0  105

# %% [markdown]
# ## Висновки :
# 1. Датасет повністю заповнений — чудово підходить для аналізу.
# 2. Найдорожчі книги частіше з'являються у жанрі Non Fiction та Fiction.
# 3. Книга з найбільшою кількістю відгуків Where the Crawdads Sing
# 4. Найдорощя книга з ТОП-50 є Publication Manual of the American Psychological Association
